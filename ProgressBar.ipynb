# %%
 
with tqdm(total=len(ls)) as pbar:
    for idx, l in enumerate(ls):
        dosomething(l)
        if idx % 5 == 0:
            pbar.update(5)
#이런 느낌으로 처리하면 좀 괜찮지않을까요?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ec858d8d7252> in <module>()
#       1
# ----> 2 with tqdm(total=len(ls)) as pbar:
#       3    for idx, l in enumerate(ls):
#       4        dosomething(l)
#       5        if idx % 5 == 0:
#
# NameError: name 'tqdm' is not defined
