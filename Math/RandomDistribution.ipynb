# %%
import random
import collections
import math

# %%
r=[]
for i in range(1000):
    r.append (random.random())

print (collections.Counter([math.floor(x*10) for x in r]))
# Out:
# Counter({0: 125, 4: 103, 3: 100, 1: 100, 8: 99, 9: 98, 5: 98, 6: 93, 2: 93, 7: 91})

# %%
import numpy as np

# %%
n = np.random.randn (1000)

print(np.mean(n))
print (np.std(n))
# Out:
# -0.04055445887874502
# 0.9980251519136242
