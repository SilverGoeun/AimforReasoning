# %% [markdown]
# # **변수선언**
#
# 내장함수가 있을 수 있어서 변수 선언할 때 주의
# snake표기법: 다 소문자 띄어쓰기는 _

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'get_ipython',
#  'quit']

# %% [markdown]
# 정수형
#
# 다른 언어와 다르게 자리수의 제한이 없다

# %% [markdown]
# F 스트링
#
# 변수에 있는 값을 문자열에 넣고 싶을때의 formatting방법 (파이썬 3.6부터)

# %%
a= '철수'
b= f'{a}는 길을 걷는다'
print (b)
# Out:
# 철수는 길을 걷는다

# %%
c='영희'
a + " " + c
# Out:
# '철수 영희'

# %%
True, False
# Out:
# (True, False)

# %%
#R에서는 모두 대문자
TRUE, FALSE

#참고로 None이라는 값과는 다른 값임 (이것은 없다를 의미)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1e26e570ddf4> in <module>()
# ----> 1 TRUE, FALSE
#
# NameError: name 'TRUE' is not defined

# %% [markdown]
# 0이면 False 나어지는 True

# %%
bool(0.1)
# Out:
# True

# %%
bool(0.00000000000000000000000000000000000001)
# Out:
# True

# %%
#비어있는 경우는?
bool('')
# Out:
# False
