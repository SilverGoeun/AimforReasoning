# %%
import numpy as np

# %%
x = np.ones((1, 2, 3))
print (x)
# Out:
# [[[1. 1. 1.]
#   [1. 1. 1.]]]

# %%
print (np.transpose(x, (1, 0, 2)) )
# Out:
# [[[1. 1. 1.]]
#
#  [[1. 1. 1.]]]
# (2, 1, 3)

# %%
np.transpose(x, (1, 0, 2)).shape
# Out:
# (2, 1, 3)
