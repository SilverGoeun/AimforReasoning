# %% [markdown]
# # **manifold learning** 의 하나
#
# 비선형 구조의 데이터를 차원 축소

# %% [markdown]
# 비지도 학습에서는 복잡한 구조를 갖는 데이터를 더 간단한 형태로 변환하는 작업이 중요
#
# # **Local Linear Embedding **
#
# LLE는 높은 차원 공간에서 휘어지거나 뒤틀린 구조를 낮은 차원 공간에 단순 구조로 나타내는 알고리즘

# %% [markdown]
# 스위스 롤 데이터세트에 국소 선형 임베딩을 적용

# %%
from sklearn.datasets import samples_generator
from sklearn.manifold import LocallyLinearEmbedding
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# 스위스 롤 데이터세트에서 data와 color라는 서로 다른 학습 데이터 생성
data, color = samples_generator.make_swiss_roll( n_samples = 1500)

n_neighbors = 12 # 근처에 있는 점 개수
n_components = 2 # 차원 축소 후 차원 수

# 국소 선형 임베딩 모델 생성
model = LocallyLinearEmbedding ( n_neighbors= n_neighbors, n_components= n_components)

# %%
model.fit(data)
print(model.transform (data))
# Out:
# [[ 0.00142987 -0.00862234]
#  [ 0.01635934 -0.05444873]
#  [ 0.02531833 -0.03478139]
#  ...
#  [ 0.02538743  0.00988292]
#  [ 0.03593597  0.07327458]
#  [-0.02323209 -0.00463235]]

# %% [markdown]
# **매니폴드 학습**
#
# Local Linear Embedding과 t-분포 확률적 임베딩 등
#
# 비선형 데이터의 차원 축소방법을 매니폴드 학습이라고 함
