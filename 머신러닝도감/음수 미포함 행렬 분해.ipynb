# %% [markdown]
# **Non Negative Matrix Factorization**
#
# NMF는 입력 데이터와 출력 데이터 값이 모두 양수라는 성질이 있는 차원 축소 방법
#
# 이미지 데이터 등을 다룰 때 모델로 만들기 쉽다는 장점

# %%
from sklearn.decomposition import NMF
from sklearn.datasets.samples_generator import make_blobs
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# 데이터의 중심 위치 정의
centers = [[5, 10, 5], [10, 4, 10], [6, 8, 8]]

# centers를 중심으로 특징과 종속 변수 생성
X, _ = make_blobs(centers=centers)

n_components = 2 # 잠재 변수의 개수

# %%
# 음수 미포함 행렬 분해 모델 생성

model = NMF( n_components= n_components)

model.fit(X) # 학습
W = model.transform(X) # 특징 데이터를 행렬 분해해 행렬 W 저장
H = model.components_  # 특징 데이터를 행렬 분해해 행렬 H 저장

# %%
print (X.shape)
# Out:
# (100, 3)

# %%
print (W.shape)

print (H.shape)

print(W)
print(H)
# Out:
# (100, 2)
# (2, 3)
# [[1.28319099 0.18132624]
#  [0.68110385 1.08084076]
#  [0.6668302  1.17893351]
#  [0.91489544 0.78613123]
#  [0.95485    0.59092405]
#  [0.99162496 0.82256217]
#  [1.12432699 0.14904681]
#  [0.90557056 0.55872851]
#  [0.84107524 0.65974913]
#  [0.98621259 0.55826902]
#  [0.98059185 0.78711358]
#  [0.67006685 1.13082075]
#  [0.62730829 1.02502318]
#  [0.61544589 0.85999357]
#  [1.30206052 0.15502877]
#  [1.29957464 0.27010539]
#  [0.70725826 0.99780383]
#  [0.62538032 1.07293396]
#  [0.93643764 0.64577392]
#  [1.52720483 0.        ]
#  [0.89800479 0.89889461]
#  [1.05499197 0.63750883]
#  [0.55413667 0.66634915]
#  [1.21407542 0.09602718]
#  [0.99343401 0.88585385]
#  [1.35018481 0.14025675]
#  [1.28574602 0.26337861]
#  [1.11713281 0.20444549]
#  [1.23129047 0.26159559]
#  [1.20941362 0.24322687]
#  [1.03428683 0.60501854]
#  [1.35593437 0.14394753]
#  [1.3449573  0.07519116]
#  [1.26865861 0.22108827]
#  [1.25514295 0.20643924]
#  [1.25819916 0.28443794]
#  [0.63854783 1.05094081]
#  [0.68744544 1.26492373]
#  [1.32756856 0.1433436 ]
#  [1.0308797  0.41387568]
#  [0.85648345 0.61689686]
#  [0.62116278 1.20642097]
#  [1.43081998 0.40488133]
#  [0.44853828 1.13737167]
#  [0.61646559 0.87714765]
#  [0.97441492 0.55824419]
#  [0.88193994 0.73390178]
#  [0.67798196 0.87152498]
#  [0.51197738 1.1699356 ]
#  [1.26120194 0.32117198]
#  [1.31499026 0.10521957]
#  [0.80349076 0.82654684]
#  [0.66856668 0.8424241 ]
#  [1.06270092 0.74374108]
#  [0.63073078 0.98608291]
#  [1.25869436 0.01246782]
#  [0.66870803 1.14968684]
#  [0.99507982 0.79138954]
#  [1.27719129 0.16373493]
#  [0.7138663  1.04864773]
#  [0.80867983 0.74995374]
#  [1.2301128  0.13352763]
#  [0.62681709 0.8998814 ]
#  [0.77215604 1.15993085]
#  [0.57557378 0.98361191]
#  [1.0985155  0.26244761]
#  [0.92186617 0.75547397]
#  [1.26564751 0.24323595]
#  [1.11897458 0.67052664]
#  [1.39344088 0.32775592]
#  [1.34779614 0.25531702]
#  [0.59990066 0.95849164]
#  [0.9338798  0.65359486]
#  [1.38378355 0.46624436]
#  [0.88085116 0.79683001]
#  [1.48730451 0.18993753]
#  [1.48401224 0.26477747]
#  [0.74654539 0.97994987]
#  [0.60835838 1.1155992 ]
#  [0.87921569 0.61818292]
#  [0.66454686 1.0238705 ]
#  [0.8659139  0.7740738 ]
#  [0.68366245 0.95708398]
#  [1.4238728  0.33592202]
#  [1.01916177 0.71939294]
#  [0.86502843 0.66271734]
#  [0.85691966 0.73036749]
#  [0.65922957 0.90456549]
#  [0.59350577 1.06406815]
#  [0.99431199 0.94319689]
#  [0.98026694 0.51460312]
#  [1.43410488 0.05550486]
#  [0.54492412 1.00032188]
#  [0.72004879 1.08220427]
#  [0.97845619 0.78951325]
#  [0.56417726 1.11185324]
#  [0.72662701 1.11726038]
#  [1.09098495 0.74396704]
#  [1.01356572 0.73426186]
#  [1.32010898 0.26926611]]
# [[7.28923223 1.63273579 7.62419712]
#  [0.         8.97662548 0.48292688]]
