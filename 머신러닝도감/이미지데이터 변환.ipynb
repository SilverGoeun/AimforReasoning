# %% [markdown]
# https://github.com/Jpub/MLBook/blob/master/ch04.ipynb

# %% [markdown]
# # **이미지 데이터 전처리**

# %%
# !pip install --upgrade pillow

# %%
#파이썬의 이미지 처리 라이브러리 Pillow사용

from PIL import Image
import numpy as np

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# 다운로드 폴더에 이미지 받아서 올림. 투명 예쁜 0
#
# 구글에 이미지 많지만 교재에서 올린 파일로 다시 해봄
#
#  ^^;;

# %%
from google.colab import files
myupload = files.upload()
# Out:
#      <input type="file" id="files-1335d457-47e9-4312-b961-c0c01efabedd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1335d457-47e9-4312-b961-c0c01efabedd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving zero_image1.png to zero_image1.png

# %%
img = Image.open ('zero_image1.png').convert ('L')

width, height = img.size

img_pixels = []

for y in range(height):
  for x in range(width):
    img_pixels.append( img.getpixel((x, y)))

print (img_pixels)
len(img_pixels)
# Out:
# [255, 255, 170, 34, 102, 238, 255, 255, 255, 255, 34, 0, 85, 0, 170, 255, 255, 204, 0, 221, 255, 68, 119, 255, 255, 187, 51, 255, 255, 119, 119, 255, 255, 170, 119, 255, 255, 102, 119, 255, 255, 187, 68, 255, 238, 51, 136, 255, 255, 221, 17, 170, 85, 51, 255, 255, 255, 255, 153, 34, 85, 255, 255, 255]
# 64

# %% [markdown]
# 변환한 벡터 데이터로 머신러닝 모델 만들기

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
digits = datasets. load_digits()

n_samples = len( digits.images)

# %%
digits
# Out:
# {'DESCR': ".. _digits_dataset:\n\nOptical recognition of handwritten digits dataset\n--------------------------------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 5620\n    :Number of Attributes: 64\n    :Attribute Information: 8x8 image of integer pixels in the range 0..16.\n    :Missing Attribute Values: None\n    :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)\n    :Date: July; 1998\n\nThis is a copy of the test set of the UCI ML hand-written digits datasets\nhttps://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits\n\nThe data set contains images of hand-written digits: 10 classes where\neach class refers to a digit.\n\nPreprocessing programs made available by NIST were used to extract\nnormalized bitmaps of handwritten digits from a preprinted form. From a\ntotal of 43 people, 30 contributed to the training set and different 13\nto the test set. 32x32 bitmaps are divided into nonoverlapping blocks of\n4x4 and the number
# ...

# %%
# 이미지 데이터 개수를 n_samples에 저장
n_samples = len(digits.images)

# 모든 이미지 데이터의 픽셀 밝기 값을 행 벡터로 만들어 data에 저장
data = digits.images.reshape (( n_samples, -1))

model = RandomForestClassifier (n_estimators =10)

# 전체 이미지의 반을 학습
model.fit ( data[:n_samples //2], digits.target[:n_samples//2])

#전체 이미지 반을 예측
predicted = model.predict ( data[n_samples//2:])
# 예측한 이미지에 대한 종속 변수를 expected에 저장
expected = digits.target [ n_samples//2:]

#정밀도, 재현율, F값 계산 출력
print ( metrics.classification_report (expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96        88
#            1       0.88      0.80      0.84        91
#            2       0.93      0.91      0.92        86
#            3       0.86      0.85      0.85        91
#            4       0.93      0.87      0.90        92
#            5       0.91      0.88      0.89        91
#            6       0.95      0.99      0.97        91
#            7       0.89      0.97      0.92        89
#            8       0.89      0.82      0.85        88
#            9       0.82      0.91      0.86        92
#
#     accuracy                           0.90       899
#    macro avg       0.90      0.90      0.90       899
# weighted avg       0.90      0.90      0.90       899
