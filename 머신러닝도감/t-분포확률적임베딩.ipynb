# %% [markdown]
# # **t-distributed stochastic neighbor embedding** (t-SNE)
#
# 높은 차원의 데이터를 2 차원 또는 3차원으로 축소시켜 시각화
#
# 데이터 구조를 이해하는데 도움을 준다.

# %%
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits

# %%
data = load_digits()

n_components = 2
 
model = TSNE (n_components= n_components)

# %%
print(model.fit_transform(data.data))
# Out:
# [[  0.6152602 -57.486755 ]
#  [-31.74626     0.373092 ]
#  [-22.256847   23.983023 ]
#  ...
#  [-16.605486    8.805403 ]
#  [  7.2462125 -13.905806 ]
#  [ -9.57492     6.585906 ]]
