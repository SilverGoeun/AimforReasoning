# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# %cd /content/drive/My Drive/Colab Notebooks/전처리/data-wrangling/data/chp3
# !pwd
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/전처리/data-wrangling/data/chp3
# /content/drive/My Drive/Colab Notebooks/전처리/data-wrangling/data/chp3

# %%
import csv

csvfile = open('data-text.csv')
#rb : read binary
# w : write

reader = csv.reader (csvfile)

for row in reader:
    print (row)

# %%
#딕셔너리로 바꾸기
import csv

csvfile = open( 'data-text.csv')
reader = csv.DictReader (csvfile)

for row in reader:
    print (row)

# %%
import json

json_data = open ('data-text.json').read()

data = json.loads(json_data)

for item in data:
    print (item)

# %%
filename = 'data-text.json'
type ( open(filename, 'rb'))
# Out:
# _io.BufferedReader

# %%
filename = 'data-text.json'
print (type ( open(filename, 'r')))
type ( open(filename).read())
# Out:
# <class '_io.TextIOWrapper'>
# str

# %%
from xml.etree import ElementTree as ET

tree = ET.parse('data-text.xml')
root = tree.getroot()
print (root)

data = root.find('Data')

all_data = []
# Out:
# <Element 'GHO' at 0x7f2e0008fea8>

# %%
for observation in data:
    record = {}
    for item in observation:

        lookup_key = item.attrib.keys()[0]

        if lookup_key == 'Numeric':
            rec_key = 'NUMERIC'
            rec_value = item.attrib['Numeric']
        else:
            rec_key = item.attrib[lookup_key]
            rec_value = item.attrib['Code']

        record[rec_key] = rec_value
    all_data.append(record)

print (all_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a9e06118c56a> in <module>()
#       3     for item in observation:
#       4
# ----> 5         lookup_key = item.attrib.keys()[0]
#       6
#       7         if lookup_key == 'Numeric':
#
# TypeError: 'dict_keys' object does not support indexing
