# %%
import tensorflow as tf

# %%
@tf.function
def add_1_or_10( x, b):
    if b:
        x += 1.
    else:
        x += 10.
    return x

result = add_1_or_10(tf.constant(2.), True).numpy()
print(result)
# Out:
# 3.0
