# %%
def crash_course(dltr):
    result = 0
    temp = 1

    for i in range(1, dltr):
        temp = temp * i
        for k in range(i):
            result +=temp

    return result

crash_course(4)
# Out:
# 23

# %%
import numpy as np
a= [[1,2], [2,1]]
b= [[4,1], [2,2]]

np.cross(a,b)
# Out:
# array([-7,  2])

# %%
def y(x):
    global a
    a=4
    return 0

def f(a):
    a=3
    print(a)
    return a

a=5
f(a)
print(a)
y(a)
print(a)
# Out:
# 3
# 5
# 4

# %%
np.transpose([[[1,2,3],[4,5,6]]])
# Out:
# array([[[1],
#         [4]],
#
#        [[2],
#         [5]],
#
#        [[3],
#         [6]]])
