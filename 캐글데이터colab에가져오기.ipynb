# %% [markdown]
# 케글에서 데이터셋 검색 및 다운로드
#
# !kaggle datasets list -s english-french

# %%
# 케글에 가서 받고 싶은 데이터 가져오기
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#  98% 532M/543M [00:05<00:00, 122MB/s]
# 100% 543M/543M [00:05<00:00, 105MB/s]
# sampleSubmission.csv: Skipping, found more recently modified local copy (use --force to force download)
# ...
# 100% 270M/271M [00:02<00:00, 111MB/s]
# 100% 271M/271M [00:02<00:00, 117MB/s]

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/data/.kaggle

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  train.zip
# replace train/cat.0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace train/cat.1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !rm *.zip
# Out:
# rm: cannot remove '*.zip': No such file or directory

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/data/.kaggle
